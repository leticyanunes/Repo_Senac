# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.DataFrame({'investimento_marketing': [10, 20, 30, 40, 50, 60],
                   'vendas': [100, 10, 250, 50, 500, 30]})

#Dataframe com os dados 

x = df[['investimento_marketing']]
y = df['vendas']

#treinar o modelo

modelo = LinearRegression()
modelo.fit(x,y)

#Estender os dados para previsão ate R$ 110 mil 

x_extendido = pd.DataFrame({'investimento_marketing': [70, 80, 110]})
y_pred = modelo.predict(x_extendido)

#Visualizar 

plt.Figure(figsize=(8,5))
plt.scatter(df['investimento_marketing'], df['vendas'], color = 'green')
plt.plot(x_extendido['investimento_marketing'], y_pred, color = 'orange')
plt.xlabel('Investimento em marketing (mil R$)')
plt.ylabel('Vendas (mil unidades)')
plt.title('Regrassão Linear com Previsão até R$ 110 mil')
plt.show()
